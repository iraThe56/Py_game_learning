# %%
varible_1=100
varible_2=12

print(varible_1 | varible_2)
# Out:
# 108

# %%
import numpy as np

# array = np.zeros((hight,width,4),int)
# print(array)

color_values=(0,0,0)
print(color_values)
# Out:
# (0, 0, 0)
